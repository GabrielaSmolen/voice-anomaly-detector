# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = pd.read_csv('../data/features.csv')

# %%
print(df["Label"])
len(df["Label"])
# Out:
# 0         healthy
# 1         healthy
# 2         healthy
# 3         healthy
# 4         healthy
#           ...
# 1369    unhealthy
# 1370    unhealthy
# 1371    unhealthy
# 1372    unhealthy
# 1373    unhealthy
# Name: Label, Length: 1374, dtype: object
# 1374

# %%
a = df["Label"].value_counts()

# %%
plt.bar(df["Label"], a[df["Label"]])
# Out:
# <BarContainer object of 1374 artists>

# %%
sns.violinplot(x="Label", y="Zero crossings", data=df)
# Out:
# <AxesSubplot:xlabel='Label', ylabel='Zero crossings'>

# %%
sns.violinplot(x="Label", y="Centroid AUC", data=df)
# Out:
# <AxesSubplot:xlabel='Label', ylabel='Centroid AUC'>

# %%
sns.violinplot(x="Label", y="Rolloff AUC", data=df)
# Out:
# <AxesSubplot:xlabel='Label', ylabel='Rolloff AUC'>

# %%
sns.violinplot(x="Label", y="Centroid mean", data=df)
# Out:
# <AxesSubplot:xlabel='Label', ylabel='Centroid mean'>

# %%
sns.violinplot(x="Label", y="Rolloff mean", data=df)
# Out:
# <AxesSubplot:xlabel='Label', ylabel='Rolloff mean'>

# %%
sns.violinplot(x="Label", y="Centroid STD", data=df)
# Out:
# <AxesSubplot:xlabel='Label', ylabel='Centroid STD'>

# %%
sns.violinplot(x="Label", y="Rolloff STD", data=df)
# Out:
# <AxesSubplot:xlabel='Label', ylabel='Rolloff STD'>

# %%
sns.violinplot(x="Label", y="Centroid p-t-p value", data=df)
# Out:
# <AxesSubplot:xlabel='Label', ylabel='Centroid p-t-p value'>

# %%
sns.violinplot(x="Label", y="Rolloff p-t-p value", data=df)
# Out:
# <AxesSubplot:xlabel='Label', ylabel='Rolloff p-t-p value'>

# %%
sns.violinplot(x="Label", y="MFCC mean 1", data=df)
# Out:
# <AxesSubplot:xlabel='Label', ylabel='MFCC mean 1'>

# %%
sns.violinplot(x="Label", y="MFCC mean 2", data=df)
# Out:
# <AxesSubplot:xlabel='Label', ylabel='MFCC mean 2'>

# %%
sns.violinplot(x="Label", y="MFCC mean 3", data=df)
# Out:
# <AxesSubplot:xlabel='Label', ylabel='MFCC mean 3'>

# %%
sns.violinplot(x="Label", y="MFCC mean 4", data=df)
# Out:
# <AxesSubplot:xlabel='Label', ylabel='MFCC mean 4'>

# %%
sns.violinplot(x="Label", y="MFCC mean 5", data=df)
# Out:
# <AxesSubplot:xlabel='Label', ylabel='MFCC mean 5'>

# %%
sns.violinplot(x="Label", y="MFCC mean 6", data=df)
# Out:
# <AxesSubplot:xlabel='Label', ylabel='MFCC mean 6'>

# %%
sns.violinplot(x="Label", y="MFCC mean 7", data=df)
# Out:
# <AxesSubplot:xlabel='Label', ylabel='MFCC mean 7'>

# %%
sns.violinplot(x="Label", y="MFCC mean 8", data=df)
# Out:
# <AxesSubplot:xlabel='Label', ylabel='MFCC mean 8'>

# %%
sns.violinplot(x="Label", y="MFCC mean 9", data=df)
# Out:
# <AxesSubplot:xlabel='Label', ylabel='MFCC mean 9'>

# %%
sns.violinplot(x="Label", y="MFCC mean 10", data=df)
# Out:
# <AxesSubplot:xlabel='Label', ylabel='MFCC mean 10'>

# %%
sns.violinplot(x="Label", y="MFCC mean 11", data=df)
# Out:
# <AxesSubplot:xlabel='Label', ylabel='MFCC mean 11'>

# %%
sns.violinplot(x="Label", y="MFCC mean 12", data=df)
# Out:
# <AxesSubplot:xlabel='Label', ylabel='MFCC mean 12'>

# %%
sns.violinplot(x="Label", y="MFCC mean 13", data=df)
# Out:
# <AxesSubplot:xlabel='Label', ylabel='MFCC mean 13'>

# %%
feats_names = ['MFCC max_min 1', 'MFCC max_min 2','MFCC max_min 3',
       'MFCC max_min 4', 'MFCC max_min 5', 'MFCC max_min 6',
       'MFCC max_min 7', 'MFCC max_min 8', 'MFCC max_min 9',
       'MFCC max_min 10', 'MFCC max_min 11', 'MFCC max_min 12']

# %%
for feat_name in feats_names:
    plt.figure()
    sns.violinplot(x="Label", y=feat_name, data=df)
