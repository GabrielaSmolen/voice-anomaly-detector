# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = pd.read_csv('../data/features.csv')

# %%
print(df["Label"])
len(df["Label"])
# Out:
# 0         healthy
# 1         healthy
# 2         healthy
# 3         healthy
# 4         healthy
#           ...
# 2036    unhealthy
# 2037    unhealthy
# 2038    unhealthy
# 2039    unhealthy
# 2040    unhealthy
# Name: Label, Length: 2041, dtype: object
# 2041

# %%
a = df["Label"].value_counts()

# %%
plt.bar(df["Label"], a[df["Label"]])
# Out:
# <BarContainer object of 2041 artists>

# %%
feats_names = ['Zero crossings', 'MFCC mean 1', 'MFCC mean 2', 'MFCC mean 3', 'MFCC mean 4', 'MFCC mean 5',
       'MFCC mean 6', 'MFCC mean 7', 'MFCC mean 8', 'MFCC mean 9', 'MFCC mean 10',
       'MFCC mean 11', 'MFCC mean 12', 'MFCC mean 13', 'HNR', 'f_0', 'Jitter']

# %%
for feat_name in feats_names:
    plt.figure()
    sns.boxplot(x="Label", y=feat_name, data=df)
